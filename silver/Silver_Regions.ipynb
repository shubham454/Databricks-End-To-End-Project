# %%
df = spark.read.table("db_dlt_proj.bronze.regions")
# df.show()

# %%
df.write.format("delta").mode("overwrite").save("/Volumes/db_dlt_proj/ext_location/silver_external_location/regions")

df.write.format("delta")\
        .mode("overwrite")\
        .saveAsTable("db_dlt_proj.silver.regions")
